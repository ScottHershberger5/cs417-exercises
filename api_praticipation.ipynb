# %% [markdown]
# <a href="https://colab.research.google.com/github/ScottHershberger5/cs417-exercises/blob/main/api_praticipation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 60,
    "longitude": -23,
    "current_weather": True
}

url2 = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 60,
    "longitude": -23,
    "current_weather": True
}

response = requests.get(url, params=params) #HTTP requests the data from the HTTP server​
data = response.json() #turns the response into a json file​ (dictonary)
print(data)
print(data["current_weather"]["temperature"]) #takes the values of the keys in the dictonary

print(data['current_weather']['time'])
# Out:
# {'latitude': 60.005535, 'longitude': -22.989975, 'generationtime_ms': 50.438523292541504, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 0.0, 'current_weather_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature': '°C', 'windspeed': 'km/h', 'winddirection': '°', 'is_day': '', 'weathercode': 'wmo code'}, 'current_weather': {'time': '2026-04-08T14:00', 'interval': 900, 'temperature': 7.1, 'windspeed': 68.8, 'winddirection': 214, 'is_day': 1, 'weathercode': 53}}
# 7.1
# 2026-04-08T14:00
